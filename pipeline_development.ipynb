# %%
from pathlib import Path

import numpy as np
import pandas as pd
import tifffile as tiff
from cellpose import models
from skimage.measure import regionprops_table

import torch

# %%
BASE_DIR = Path.cwd()
DATA_DIR = BASE_DIR / "data"
OUTPUT_DIR = BASE_DIR / "outputs" / "cellpose_python"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

COND_PATH = DATA_DIR / "raw_mask_condensates" / "C2-raw_stack_sample2_5.tif"
NUC_PATH  = DATA_DIR / "raw_mask_nuclei" / "C1-raw_stack_sample2_5.tif"

print("Condensate file exists: ", COND_PATH.exists())
print("Nuclei file exists: ", NUC_PATH.exists())
# Out:
# Condensate file exists:  True
# Nuclei file exists:  True

# %%
cond_stack = tiff.imread(COND_PATH)
nuc_stack = tiff.imread(NUC_PATH)

print("Condensates shape:", cond_stack.shape)
print("Nuclei shape:", nuc_stack.shape)
print("Condensates dtype:", cond_stack.dtype)
print("Nuclei dtype:", nuc_stack.dtype)
# Out:
# Condensates shape: (55, 1800, 1800)
# Nuclei shape: (55, 1800, 1800)
# Condensates dtype: uint16
# Nuclei dtype: uint16

# %%
cond_model = models.CellposeModel(gpu=True)
nuc_model  = models.CellposeModel(gpu=True)

# %%
from cellpose import core
print("GPU working:", core.use_gpu())
# Out:
# GPU working: True

# %%
def run_cellpose_stack(stack, model, object_name="objects", diameter=None):
    mask_stack = []
    measurements = []

    for z in range(stack.shape[0]):
        img = stack[z]

        masks, flows, styles= model.eval(
            img,
            diameter=diameter,
            channels=[0, 0]
        )

        mask_stack.append(masks.astype(np.int32))

        props = regionprops_table(
            masks,
            intensity_image=img,
            properties=["label", "area", "centroid", "mean_intensity"]
        )

        df = pd.DataFrame(props)
        df["z"] = z
        measurements.append(df)

        print(f"{object_name} slice {z}: {masks.max()} objects")

    mask_stack = np.stack(mask_stack)
    measurements_df = pd.concat(measurements, ignore_index=True)

    return mask_stack, measurements_df

# %%
cond_masks, cond_df = run_cellpose_stack(
    cond_stack,
    cond_model,
    object_name="condensates",
    diameter=None
)
# Out:
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 0: 0 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 1: 0 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 2: 1 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 3: 1 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 4: 5 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 5: 6 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 6: 10 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 7: 13 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 8: 12 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 9: 17 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 10: 10 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 11: 8 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 12: 12 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 13: 9 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 14: 7 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 15: 8 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 16: 9 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 17: 11 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 18: 15 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 19: 23 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 20: 36 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 21: 27 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 22: 38 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 23: 21 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 24: 33 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 25: 33 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 26: 39 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 27: 35 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 28: 28 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 29: 24 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 30: 16 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 31: 16 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 32: 15 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 33: 15 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 34: 12 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 35: 14 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 36: 14 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 37: 16 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 38: 11 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 39: 9 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 40: 10 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 41: 12 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 42: 13 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 43: 9 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 44: 3 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 45: 6 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 46: 3 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 47: 4 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 48: 4 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 49: 5 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 50: 4 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 51: 4 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 52: 6 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# condensates slice 53: 2 objects
# condensates slice 54: 2 objects

# %%
nuc_masks, nuc_df = run_cellpose_stack(
    nuc_stack,
    nuc_model,
    object_name="nuclei",
    diameter=None
)
# Out:
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# nuclei slice 0: 4 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# nuclei slice 1: 5 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# nuclei slice 2: 5 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# nuclei slice 3: 8 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# nuclei slice 4: 15 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# nuclei slice 5: 12 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# nuclei slice 6: 24 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# nuclei slice 7: 67 objects
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# nuclei slice 8: 137 objects
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 nuc_masks, nuc_df = run_cellpose_stack(
#       2     nuc_stack,
#       3     nuc_model,
#       4     object_name="nuclei",
#       5     diameter=None
#       6 )
#
# Cell In[7], line 8, in run_cellpose_stack(stack, model, object_name, diameter)
#       5 for z in range(stack.shape[0]):
#       6     img = stack[z]
# ----> 8     masks, flows, styles= model.eval(
#       9         img,
#      10         diameter=diameter,
#      11         channels=[0, 0]
#      12     )
#      14     mask_stack.append(masks.astype(np.int32))
#      16     props = regionprops_table(
#      17         masks,
#      18         intensity_image=img,
#      19         properties=["label", "area", "centroid", "mean_intensity"]
#      20     )
#
# File ~/code/research_lab/csbio-venv/lib/python3.12/site-packages/cellpose/models.py:359, in CellposeModel.eval(self, x, batch_size, resample, channels, channel_axis, z_axis, normalize, invert, rescale, diameter, flow_threshold, cellprob_threshold, do_3D, anisotropy, flow3D_smooth, stitch_threshold, min_size, max_size_fraction, niter, augment, tile_overlap, bsize, compute_masks, progress)
#     357     niter_scale = 1 if image_scaling is None else image_scaling
#     358     niter = int(200/niter_scale) if niter is None or niter == 0 else niter
# --> 359     masks = self._compute_masks((Lz_0 or nimg, Ly_0, Lx_0), dP, cellprob, flow_threshold=flow_threshold,
#     360                     cellprob_threshold=cellprob_threshold, min_size=min_size,
#     361                 max_size_fraction=max_size_fraction, niter=niter,
#     362                 stitch_threshold=stitch_threshold, do_3D=do_3D)
#     363 else:
#     364     masks = np.zeros(0) #pass back zeros if not compute_masks
#
# File ~/code/research_lab/csbio-venv/lib/python3.12/site-packages/cellpose/models.py:442, in CellposeModel._compute_masks(self, shape, dP, cellprob, flow_threshold, cellprob_threshold, min_size, max_size_fraction, niter, do_3D, stitch_threshold)
#     439 for i in iterator:
#     440     # turn off min_size for 3D stitching
#     441     min_size0 = min_size if stitch_threshold == 0 or nimg == 1 else -1
# --> 442     outputs = dynamics.resize_and_compute_masks(
#     443         dP[:, i], cellprob[i],
#     444         niter=niter, cellprob_threshold=cellprob_threshold,
#     445         flow_threshold=flow_threshold, resize=resize,
#     446         min_size=min_size0, max_size_fraction=max_size_fraction,
#     447         device=self.device)
#     448     if i==0 and nimg > 1:
#     449         masks = np.zeros((nimg, shape[1], shape[2]), outputs.dtype)
#
# File ~/code/research_lab/csbio-venv/lib/python3.12/site-packages/cellpose/dynamics.py:610, in resize_and_compute_masks(dP, cellprob, niter, cellprob_threshold, flow_threshold, do_3D, min_size, max_size_fraction, resize, device)
#     587 def resize_and_compute_masks(dP, cellprob, niter=200, cellprob_threshold=0.0,
#     588                              flow_threshold=0.4, do_3D=False, min_size=15,
#     589                              max_size_fraction=0.4, resize=None, device=torch.device("cpu")):
#     590     """Compute masks using dynamics from dP and cellprob, and resizes masks if resize is not None.
#     591
#     592     Args:
#    (...)    608         tuple: A tuple containing the computed masks and the final pixel locations.
#     609     """
# --> 610     mask = compute_masks(dP, cellprob, niter=niter,
#     611                             cellprob_threshold=cellprob_threshold,
#     612                             flow_threshold=flow_threshold, do_3D=do_3D,
#     613                             max_size_fraction=max_size_fraction,
#     614                             device=device)
#     616     if resize is not None:
#     617         dynamics_logger.warning("Resizing is deprecated in v4.0.1+")
#
# File ~/code/research_lab/csbio-venv/lib/python3.12/site-packages/cellpose/dynamics.py:672, in compute_masks(dP, cellprob, p, niter, cellprob_threshold, flow_threshold, do_3D, min_size, max_size_fraction, device)
#     669 if not do_3D:
#     670     if mask.max() > 0 and flow_threshold is not None and flow_threshold > 0:
#     671         # make sure labels are unique at output of get_masks
# --> 672         mask = remove_bad_flow_masks(mask, dP, threshold=flow_threshold,
#     673                                      device=device)
#     675 if mask.max() < 2**16 and mask.dtype != "uint16":
#     676     mask = mask.astype("uint16")
#
# File ~/code/research_lab/csbio-venv/lib/python3.12/site-packages/cellpose/dynamics.py:443, in remove_bad_flow_masks(masks, flows, threshold, device)
#     440         dynamics_logger.info("turn off QC step with flow_threshold=0 if too slow")
#     441         device0 = torch.device("cpu")
# --> 443 merrors, _ = flow_error(masks, flows, device0)
#     444 badi = 1 + (merrors > threshold).nonzero()[0]
#     445 masks[np.isin(masks, badi)] = 0
#
# File ~/code/research_lab/csbio-venv/lib/python3.12/site-packages/cellpose/dynamics.py:300, in flow_error(maski, dP_net, device)
#     297     return
#     299 # flows predicted from estimated masks
# --> 300 dP_masks = masks_to_flows_gpu(maski, device=device)
#     301 # difference between predicted flows vs mask flows
#     302 flow_errors = np.zeros(maski.max())
#
# File ~/code/research_lab/csbio-venv/lib/python3.12/site-packages/cellpose/dynamics.py:139, in masks_to_flows_gpu(masks, device, niter)
#     137 ### run diffusion
#     138 n_iter = 2 * ext.max() if niter is None else niter
# --> 139 mu = _extend_centers_gpu(neighbors, meds_p, isneighbor, shape, n_iter=n_iter,
#     140                         device=device)
#     141 mu = mu.astype("float64")
#     143 # new normalization
#
# File ~/code/research_lab/csbio-venv/lib/python3.12/site-packages/cellpose/dynamics.py:46, in _extend_centers_gpu(neighbors, meds, isneighbor, shape, n_iter, device)
#      44     Tneigh = T[tuple(neighbors)]
#      45     Tneigh *= isneighbor
# ---> 46     T[tuple(neighbors[:, 0])] = Tneigh.mean(axis=0)
#      47 del meds, isneighbor, Tneigh
#      49 if T.ndim == 2:
#
# KeyboardInterrupt:

# %%
print("Condensate mask stack shape:", cond_masks.shape)
print("Nuclei mask stack shape:", nuc_masks.shape)

display(cond_df.head())
display(nuc_df.head())

# %%
print("Condensate mask stack shape:", cond_masks.shape)
print("Nuclei mask stack shape:", nuc_masks.shape)

display(cond_df.head())
display(nuc_df.head())
# Out:
# Condensate mask stack shape: (55, 1800, 1800)
# Nuclei mask stack shape: (55, 1800, 1800)
#    label     area   centroid-0  centroid-1  mean_intensity  z
# 0      1  17708.0   235.162864  344.410549      158.912469  2
# 1      1  13512.0   232.776569  349.754070      168.239491  3
# 2      1  15782.0   237.280383  340.065264      164.490559  4
# 3      2  10458.0   911.121916  540.136546      151.896921  4
# 4      3   5009.0  1019.505690  430.673188      160.101417  4
#    label     area   centroid-0  centroid-1  mean_intensity  z
# 0      1   9504.0   678.554819  805.281145      141.715909  0
# 1      2  15848.0   910.926426  412.241608      154.784326  0
# 2      3   9307.0   919.958956  533.076072      155.566026  0
# 3      4   3297.0  1624.555050  955.946921      158.498029  0
# 4      1   9799.0   677.600776  802.433616      143.778345  1

# %%
# ================================
# COMPUTE PARTITION COEFFICIENT
# ================================

cond_intensities = []
dilute_intensities = []

for z in range(cond_stack.shape[0]):
    cond_mask = cond_masks[z] > 0
    nuc_mask  = nuc_masks[z] > 0

    img = cond_stack[z]  # use condensate channel for intensity

    # Condensate pixels inside nuclei
    cond_pixels = img[cond_mask & nuc_mask]

    # Dilute phase = nucleus but NOT condensate
    dilute_pixels = img[(nuc_mask) & (~cond_mask)]

    if len(cond_pixels) > 0:
        cond_intensities.append(np.mean(cond_pixels))

    if len(dilute_pixels) > 0:
        dilute_intensities.append(np.mean(dilute_pixels))


# Final averages across slices
cond_density = np.mean(cond_intensities)
dilute_density = np.mean(dilute_intensities)

partition_coefficient = cond_density / dilute_density

print("Condensate density:", cond_density)
print("Dilute density:", dilute_density)
print("Partition coefficient:", partition_coefficient)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5 cond_intensities = []
#       6 dilute_intensities = []
# ----> 8 for z in range(cond_stack.shape[0]):
#       9     cond_mask = cond_masks[z] > 0
#      10     nuc_mask  = nuc_masks[z] > 0
#
# NameError: name 'cond_stack' is not defined

# %%
tiff.imwrite(OUTPUT_DIR / "condensate_masks.tif", cond_masks.astype(np.int32))
tiff.imwrite(OUTPUT_DIR / "nuclei_masks.tif", nuc_masks.astype(np.int32))

cond_df.to_csv(OUTPUT_DIR / "condensate_measurements.csv", index=False)
nuc_df.to_csv(OUTPUT_DIR / "nuclei_measurements.csv", index=False)

print("Saved to:", OUTPUT_DIR)
# Out:
# Saved to: /Users/danielchang/code/research_lab/outputs/cellpose_python
